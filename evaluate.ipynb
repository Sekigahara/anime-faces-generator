# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
generator = tf.keras.models.load_model("utils//first_succed_generator.h5")
discriminator = tf.keras.models.load_model("utils//first_succed_discriminator.h5")
gan = tf.keras.models.load_model("utils//first_succed_gan.h5")
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 32, 32, 128)       9728
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               8388864
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 256)               0
# ...

# %%
noise = np.random.uniform(-1,1,size=[5,100])

im = generator.predict(noise)
